# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import time

navegador = webdriver.Chrome()

def open_web_browser_in_microsoft_docs_page():
    
    print("Open page: https://docs.microsoft.com/pt-br/sql/t-sql/functions/functions?view=sql-server-ver15 ")
    print("Waiting for http response...")

    navegador.get("https://docs.microsoft.com/pt-br/sql/t-sql/functions/functions?view=sql-server-ver15")

    
    wait_until_the_page_is_fully_loaded('tree-item')
    print("Pagina aberta")
    
    
def wait_until_the_page_is_fully_loaded(element):
    
    while len(navegador.find_elements_by_class_name(element)) < 1:  
        time.sleep(1)


def get_sintax_from_all_versions_of_tsql():
    
    index_of_type_of_command = 3
    ii = 0
    index_of_command = 2
    index_of_list_of_type_of_commands = 0
    number_of_versions_left = 3

    while(number_of_versions_left > 0):
        

        if(number_of_versions_left == 3):
            print('T-SQL 2019:')

        elif(number_of_versions_left == 2):
            navegador.get("https://docs.microsoft.com/pt-br/sql/t-sql/functions/functions?view=sql-server-2017")
            wait_until_the_page_is_fully_loaded('tree-item')
            print('T-SQL 2017:')

        elif(number_of_versions_left == 1):
            navegador.get("https://docs.microsoft.com/pt-br/sql/t-sql/functions/functions?view=sql-server-2016")
            wait_until_the_page_is_fully_loaded('tree-item')
            print('T-SQL 2016:')


        index_of_type_of_command = 3

        type_of_commands = []
        commands = []

        while(len(navegador.find_elements_by_xpath('/html/body/div[2]/div/div/nav/ul/li[22]/ul/li[14]/ul/li['+(str)(11+index_of_list_of_type_of_commands)+']')) >= 1):
            
            while(len(navegador.find_elements_by_xpath('/html/body/div[2]/div/div/nav/ul/li[22]/ul/li[14]/ul/li['+(str)(11+index_of_list_of_type_of_commands)+']/ul/li['+(str)(index_of_type_of_command)+']')) >= 1):
                navegador.find_element_by_xpath('/html/body/div[2]/div/div/nav/ul/li[22]/ul/li[14]/ul/li['+(str)(11+index_of_list_of_type_of_commands)+']/ul/li['+(str)(index_of_type_of_command)+']').click()
                time.sleep(0.1)
                
                while(len(navegador.find_elements_by_xpath('/html/body/div[2]/div/div/nav/ul/li[22]/ul/li[14]/ul/li['+(str)(11+index_of_list_of_type_of_commands)+']/ul/li['+(str)(index_of_type_of_command)+']/ul/li['+(str)(index_of_command)+']')) >= 1):
                    commands.append(navegador.find_element_by_xpath('/html/body/div[2]/div/div/nav/ul/li[22]/ul/li[14]/ul/li['+(str)(11+index_of_list_of_type_of_commands)+']/ul/li['+(str)(index_of_type_of_command)+']/ul/li['+(str)(index_of_command)+']').text)
                    index_of_command = index_of_command + 1
                    
                type_of_commands.append(navegador.find_element_by_xpath('/html/body/div[2]/div/div/nav/ul/li[22]/ul/li[14]/ul/li['+(str)(11+index_of_list_of_type_of_commands)+']/ul/li['+(str)(index_of_type_of_command)+']/ul/li[1]').text)
                if(index_of_list_of_type_of_commands == 0):
                    print(type_of_commands[index_of_type_of_command-3])
                    
                elif(index_of_list_of_type_of_commands != 0):
                    print(type_of_commands[ii])

                index_of_type_of_command = index_of_type_of_command + 1
                ii = ii + 1
                index_of_command = 2

            index_of_type_of_command = 2
            print(index_of_list_of_type_of_commands)
            index_of_list_of_type_of_commands = index_of_list_of_type_of_commands + 1
            #navegador.execute_script("window.scrollTo(0,window.scrollY + 500)")

            if(number_of_versions_left == 3):
                
                if(index_of_list_of_type_of_commands == 1):
                    navegador.get("https://docs.microsoft.com/pt-br/sql/t-sql/language-elements/language-elements-transact-sql?view=sql-server-ver15")

                elif(index_of_list_of_type_of_commands == 2):
                    navegador.get("https://docs.microsoft.com/pt-br/sql/t-sql/queries/queries?view=sql-server-ver15")

                elif(index_of_list_of_type_of_commands == 3):
                    navegador.get("https://docs.microsoft.com/pt-br/sql/t-sql/statements/statements?view=sql-server-ver15")



            elif(number_of_versions_left == 2):
                
                if(index_of_list_of_type_of_commands == 1):
                    navegador.get("https://docs.microsoft.com/pt-br/sql/t-sql/language-elements/language-elements-transact-sql?view=sql-server-ver15")

                elif(index_of_list_of_type_of_commands == 2):
                    navegador.get("https://docs.microsoft.com/pt-br/sql/t-sql/queries/queries?view=sql-server-2017")

                elif(index_of_list_of_type_of_commands == 3):
                    navegador.get("https://docs.microsoft.com/pt-br/sql/t-sql/statements/statements?view=sql-server-2017")


            elif(number_of_versions_left == 1):
                
                if(index_of_list_of_type_of_commands == 1):
                    navegador.get("https://docs.microsoft.com/pt-br/sql/t-sql/language-elements/language-elements-transact-sql?view=sql-server-2016")

                elif(index_of_list_of_type_of_commands == 2):
                    navegador.get("https://docs.microsoft.com/pt-br/sql/t-sql/queries/queries?view=sql-server-2016")

                elif(index_of_list_of_type_of_commands == 3):
                    navegador.get("https://docs.microsoft.com/pt-br/sql/t-sql/statements/statements?view=sql-server-2016")
                    

            wait_until_the_page_is_fully_loaded('tree-item')


        ii = 0            
        index_of_list_of_type_of_commands = 0
        number_of_versions_left = number_of_versions_left - 1

        print('Type of commands: ')    
        print(type_of_commands)
        print('Commands: ')    
        print(commands)

        
        
open_web_browser_and_open_microsoft_docs_page()
get_sintax_from_all_versions_of_tsql()
# Out:
# Open page: https://docs.microsoft.com/pt-br/sql/t-sql/functions/functions?view=sql-server-ver15
# Waiting for http response...
# Pagina aberta
# T-SQL 2019:
# Agregado
# Analítico
# Ordenação – COLLATIONPROPERTY
# Configuração
# Conversão
# Criptográfica
# Cursor
# Tipo de dados
# Data e hora
# JSON
# Matemático
# CHOOSE
# Metadados
# Classificação
# PUBLISHINGSERVERNAME
# Segurança
# String
# Sistema
# Estatísticas do sistema
# TEXTPTR
# Gatilho
# 0
# Execute
# Controle de fluxo
# Cursores
# Expressões
# Visão geral
# Transactions
# Variáveis
# 1
# AT TIME ZONE
# SELECT
# FROM além de JOIN, APPLY, PIVOT
# WHERE
# Dicas
# Predicados
# 2
# ADICIONAR CLASSIFICAÇAÕ DE SENSIBILIDADE
# APPLICATION ROLE
# BACKUP
# AGGREGATE
# cláusula COLLATE
# AGGREGATE
# ADD SIGNATURE
# BEGIN CONVERSATION TIMER
# SET
# 3
# Type of commands:
# ...
